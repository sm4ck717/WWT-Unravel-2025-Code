# %%
import pandas as pd

# %% [markdown]
# # Test Data

# %%
test_data = pd.read_csv('test_data_question.csv')
test_data
# Out:
#      CUSTOMER_ID  STORE_NUMBER    ORDER_ID ORDER_CHANNEL_NAME  \
# 0      997177535          4915  9351345556            Digital
# 1      345593831           949  3595377080            Digital
# 2      160955031          2249  4071757785            Digital
# 3      890671991          4154  3931766769            Digital
# 4       73989021          4094  3739700809            Digital
# ..           ...           ...         ...                ...
# 995    199551661          4915  5790578362            Digital
# 996    324907688          1161   371107248            Digital
# 997    688871063           949  7519184133            Digital
# 998    529892223          4750  8800902863            Digital
# 999    986902731          1731  2611475190            Digital
#
#     ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME CUSTOMER_TYPE  \
# 0                     WWT                ToGo         Guest
# 1                     WWT                ToGo    Registered
# ...

# %%
test_data.nunique()
# Out:
# CUSTOMER_ID              1000
# STORE_NUMBER               38
# ORDER_ID                 1000
# ORDER_CHANNEL_NAME          1
# ORDER_SUBCHANNEL_NAME       1
# ORDER_OCCASION_NAME         2
# CUSTOMER_TYPE               3
# item1                      75
# item2                      79
# item3                      79
# dtype: int64

# %%
test_data['CUSTOMER_TYPE'].value_counts()
# Out:
# CUSTOMER_TYPE
# Registered    753
# Guest         246
# eClub           1
# Name: count, dtype: int64

# %%
test_data['ORDER_CHANNEL_NAME'].value_counts()
# Out:
# ORDER_CHANNEL_NAME
# Digital    1000
# Name: count, dtype: int64

# %%
test_data['ORDER_SUBCHANNEL_NAME'].value_counts()
# Out:
# ORDER_SUBCHANNEL_NAME
# WWT    1000
# Name: count, dtype: int64

# %%
test_data['ORDER_OCCASION_NAME'].value_counts()
# Out:
# ORDER_OCCASION_NAME
# ToGo        853
# Delivery    147
# Name: count, dtype: int64

# %%
test_data['item1'].unique()
# Out:
# array(['Chicken Sub Combo', 'Regular Buffalo Fries',
#        'Large Buffalo Fries', '6 pc Grilled Wings Combo',
#        '3 pc Crispy Strips Combo', '10 pc Spicy Wings',
#        'Ranch Dip - Regular', 'Fried Corn - Regular',
#        '20 pc Grilled Wings', '8 pc Spicy Wings Combo',
#        '15 pc Spicy Wings Combo', '2 pc Crispy Strips',
#        '30 pc Family Grilled Wings', 'Honey Mustard Dip - Regular',
#        '3 Strips Lunch', 'Add 5 Grilled Wings', '10 pc Grilled Wings',
#        'Chicken Sub', '20pc Spicy Feast Deal', 'Voodoo Fries - Regular',
#        '4 pc Crispy Strips', 'Fried Corn - Large',
#        '15 pc Mixed Wings Combo', '6 pc Spicy Wings Combo',
#        'Cheese Fries - Large', 'Ranch Dip - Large', '32 Oz Soda',
#        '10 pc Grilled Wings Combo', 'Veggie Sticks Spicy',
#        '10 pc Mixed Wings Combo', '6 pc Strips Meal for 2', '20 Oz Soda',
#        'Carrot Sticks', '20 pc Mixed Wings', 'Large Veggie Sticks Spicy',
# ...

# %%
test_data['item2'].unique()
# Out:
# array(['Ranch Dip - Regular', '10 pc Spicy Wings', '20 pc Grilled Wings',
#        'Chicken Sub Combo', 'Add 5 Spicy Wings', 'Chicken Sub',
#        '8 pc Grilled Wings Combo', '5 pc Crispy Strips Combo',
#        '6 pc Grilled Wings Combo', '6 pc Spicy Wings Combo',
#        '2 pc Crispy Strips', 'Large Buffalo Fries', '10 pc Grilled Wings',
#        'Ranch Dip - Large', '20 Oz Soda', '6 pc Mixed Wings Combo',
#        '15 pc Grilled Wings', '8 pc Spicy Wings Combo',
#        'Triple Chocolate Cake', '50 pc Grilled Wings',
#        '10 pc Mixed Wings', '20 pc Mixed Wings',
#        '3 pc Crispy Strips Combo', '20pc Spicy Feast Deal',
#        'Add 5 Grilled Wings', 'Blue Cheese Dip - Regular', '32 Oz Soda',
#        '15 pc Crispy Strips', 'Regular Buffalo Fries',
#        '30 pc Spicy Wings', '10 pc Grilled Wings Combo',
#        '30 pc Family Grilled Wings', '4 pc Crispy Strips',
#        'Voodoo Fries - Regular', 'Fried Corn - Large',
# ...

# %%
test_data['item3'].unique()
# Out:
# array(['10 pc Spicy Wings Combo', '3 pc Crispy Strips Combo',
#        'Ranch Dip - Regular', 'Fried Corn - Large', 'Ranch Dip - Large',
#        'Chicken Sub', 'Veggie Sticks Spicy', '8 pc Spicy Wings Combo',
#        'Regular Buffalo Fries', 'Chicken Sub Combo',
#        'Voodoo Fries - Regular', '10 pc Spicy Wings',
#        '5 pc Crispy Strips Combo', '20pc Spicy Feast Deal',
#        '10 pc Grilled Wings Combo', '10 pc Grilled Wings',
#        'Cheese Fries - Large', '2 pc Crispy Strips',
#        '8 pc Grilled Wings Combo', 'Fried Corn - Regular',
#        '7 pc Crispy Strips', '20 Oz Soda', '15 pc Grilled Wings',
#        'Voodoo Fries - Large', 'Large Buffalo Fries', 'Carrot Sticks',
#        '6 pc Grilled Wings Combo', 'Flavor Platter', 'Veggie Sticks',
#        '15 pc Spicy Wings', '40 pc Family Mixed Wings',
#        'Large Veggie Sticks Spicy', 'Cheese Dip - Medium',
#        '4 pc Crispy Strips', '20 pc Grilled Wings',
# ...

# %% [markdown]
# # Merged Data

# %%
df = pd.read_csv('final_merged_data.csv')
df
# Out:
#            ORDER_ID  CUSTOMER_ID  STORE_NUMBER ORDER_CREATED_DATE  \
# 0        7247194287    362204699          2156         2024-07-24
# 1        7247194287    362204699          2156         2024-07-24
# 2        7247194287    362204699          2156         2024-07-24
# 3        7247194287    362204699          2156         2024-07-24
# 4         791214421    269612955          1419         2025-02-15
# ...             ...          ...           ...                ...
# 5657282  8865782702    125634365          1419         2024-11-30
# 5657283  8865782702    125634365          1419         2024-11-30
# 5657284  8030111101    125634365          4595         2024-12-16
# 5657285  8030111101    125634365          4595         2024-12-16
# 5657286  8030111101    125634365          4595         2024-12-16
#
#         ORDER_CHANNEL_NAME ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME  \
# 0                  Digital                   WWT                ToGo
# ...

# %% [markdown]
# ### Filtering out Non-edible items

# %%
non_edible_items = [
    'Order Memo Not Paid', 'Order Memo Paid', 'Order Memo Item', 'Order Memo ASAP',
    'Order Blankline 2', 'Order Blankline 1', 'Order Memo Future',
    'Plastic Fork', 'Plastic Utensils', 'Plastic Straw', 'Plastic Knife',
    'Ketchup Pack', 'Seasoning Pack', 'Extra Sauce',
    'Delivery Fee', 'Unavailable Item'
]

df_edible = df[~df['item_name'].isin(non_edible_items)]
df_edible
# Out:
#            ORDER_ID  CUSTOMER_ID  STORE_NUMBER ORDER_CREATED_DATE  \
# 1        7247194287    362204699          2156         2024-07-24
# 2        7247194287    362204699          2156         2024-07-24
# 3        7247194287    362204699          2156         2024-07-24
# 4         791214421    269612955          1419         2025-02-15
# 5         791214421    269612955          1419         2025-02-15
# ...             ...          ...           ...                ...
# 5657278  9371418183    125634365          1419         2025-01-22
# 5657281  8082200700    125634365          4595         2025-02-13
# 5657283  8865782702    125634365          1419         2024-11-30
# 5657284  8030111101    125634365          4595         2024-12-16
# 5657285  8030111101    125634365          4595         2024-12-16
#
#         ORDER_CHANNEL_NAME ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME  \
# 1                  Digital                   WWT                ToGo
# ...

# %%
df_edible.isna().sum()
# Out:
# ORDER_ID                 0
# CUSTOMER_ID              0
# STORE_NUMBER             0
# ORDER_CREATED_DATE       0
# ORDER_CHANNEL_NAME       0
# ORDER_SUBCHANNEL_NAME    0
# ORDER_OCCASION_NAME      0
# item_name                0
# item_price               0
# item_quantity            0
# CUSTOMER_TYPE            0
# CITY                     0
# STATE                    0
# POSTAL_CODE              0
# city_filled              0
# state_filled             0
# state_abbrev             0
# dtype: int64

# %%
df_edible.duplicated().sum()
# Out:
# 0

# %%
df_edible.nunique()
# Out:
# ORDER_ID                 1414410
# CUSTOMER_ID               563346
# STORE_NUMBER                  38
# ORDER_CREATED_DATE           446
# ORDER_CHANNEL_NAME             1
# ORDER_SUBCHANNEL_NAME          2
# ORDER_OCCASION_NAME            2
# item_name                    129
# item_price                  4299
# item_quantity                 60
# CUSTOMER_TYPE                  6
# CITY                          33
# STATE                         15
# POSTAL_CODE                   38
# city_filled                   33
# state_filled                  15
# state_abbrev                  15
# dtype: int64

# %%
df_edible['CUSTOMER_TYPE'].value_counts()
# Out:
# CUSTOMER_TYPE
# Registered         2291792
# Guest               519394
# eClub                 3644
# Deleted Account       1663
# Unknown                119
# Online                   5
# Name: count, dtype: int64

# %%
df_edible_cust3 = df_edible[df_edible['CUSTOMER_TYPE'].isin(['Registered', 'eClub', 'Guest'])]

df_edible_cust3
# Out:
#            ORDER_ID  CUSTOMER_ID  STORE_NUMBER ORDER_CREATED_DATE  \
# 1        7247194287    362204699          2156         2024-07-24
# 2        7247194287    362204699          2156         2024-07-24
# 3        7247194287    362204699          2156         2024-07-24
# 4         791214421    269612955          1419         2025-02-15
# 5         791214421    269612955          1419         2025-02-15
# ...             ...          ...           ...                ...
# 5657278  9371418183    125634365          1419         2025-01-22
# 5657281  8082200700    125634365          4595         2025-02-13
# 5657283  8865782702    125634365          1419         2024-11-30
# 5657284  8030111101    125634365          4595         2024-12-16
# 5657285  8030111101    125634365          4595         2024-12-16
#
#         ORDER_CHANNEL_NAME ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME  \
# 1                  Digital                   WWT                ToGo
# ...

# %%
df_edible_cust3['CUSTOMER_TYPE'].value_counts()
# Out:
# CUSTOMER_TYPE
# Registered    2291792
# Guest          519394
# eClub            3644
# Name: count, dtype: int64

# %%
df_edible_cust3['ORDER_CREATED_DATE'].min(), df_edible_cust3['ORDER_CREATED_DATE'].max()
# Out:
# ('2024-01-30', '2025-04-29')

# %% [markdown]
# # 1. Registered and eClub

# %%
df1 = df_edible_cust3[df_edible_cust3['CUSTOMER_TYPE'] != 'Guest']
df1
# Out:
#            ORDER_ID  CUSTOMER_ID  STORE_NUMBER ORDER_CREATED_DATE  \
# 1        7247194287    362204699          2156         2024-07-24
# 2        7247194287    362204699          2156         2024-07-24
# 3        7247194287    362204699          2156         2024-07-24
# 4         791214421    269612955          1419         2025-02-15
# 5         791214421    269612955          1419         2025-02-15
# ...             ...          ...           ...                ...
# 5657255  8588132902    614873531          1070         2025-02-21
# 5657256  7640314845    614873531          1070         2025-03-25
# 5657257  7640314845    614873531          1070         2025-03-25
# 5657258  7640314845    614873531          1070         2025-03-25
# 5657260  7640314845    614873531          1070         2025-03-25
#
#         ORDER_CHANNEL_NAME ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME  \
# 1                  Digital                   WWT                ToGo
# ...

# %%
df1.nunique()
# Out:
# ORDER_ID                 1141972
# CUSTOMER_ID               407837
# STORE_NUMBER                  38
# ORDER_CREATED_DATE           446
# ORDER_CHANNEL_NAME             1
# ORDER_SUBCHANNEL_NAME          1
# ORDER_OCCASION_NAME            2
# item_name                    128
# item_price                  3714
# item_quantity                 51
# CUSTOMER_TYPE                  2
# CITY                          33
# STATE                         15
# POSTAL_CODE                   38
# city_filled                   33
# state_filled                  15
# state_abbrev                  15
# dtype: int64

# %%
# Create the pivot table from your loyal customer dataframe
user_item_matrix_loyal = df1.pivot_table(
    index='CUSTOMER_ID',
    columns='item_name',
    values='item_quantity',
    aggfunc='sum',
    fill_value=0
)

user_item_matrix_loyal
# Out:
# item_name    $19.99 Crispy Feast  10 pc Grilled Wings  \
# CUSTOMER_ID
# 1588                           0                    0
# 2475                           0                    0
# 5791                           0                    0
# 6524                           0                    1
# 7771                           0                    0
# ...                          ...                  ...
# 999958453                      0                    0
# 999959082                      0                    0
# 999978358                      0                    0
# 999996591                      0                    0
# 999999303                      0                    0
#
# item_name    10 pc Grilled Wings Combo  10 pc Mixed Wings  \
# CUSTOMER_ID
# 1588                                 0                  0
# 2475                                 0                  0
# 5791                                 0                  0
# ...

# %%
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity

# Convert to a sparse matrix for efficiency
user_item_sparse_loyal = csr_matrix(user_item_matrix_loyal.values)

# Compute cosine similarity between items
item_similarity_loyal = cosine_similarity(user_item_sparse_loyal.T)

# Create the final item similarity dataframe for easy lookup
item_similarity_df_loyal = pd.DataFrame(item_similarity_loyal, index=user_item_matrix_loyal.columns, columns=user_item_matrix_loyal.columns)

print("✅ Collaborative Filtering model for loyal customers is trained.")

item_similarity_df_loyal
# Out:
# ✅ Collaborative Filtering model for loyal customers is trained.
# item_name                  $19.99 Crispy Feast  10 pc Grilled Wings  \
# item_name
# $19.99 Crispy Feast                   1.000000             0.001308
# 10 pc Grilled Wings                   0.001308             1.000000
# 10 pc Grilled Wings Combo             0.001187             0.117965
# 10 pc Mixed Wings                     0.000000             0.071402
# 10 pc Mixed Wings Combo               0.000619             0.025932
# ...                                        ...                  ...
# Veggie Sticks                         0.000000             0.083644
# Veggie Sticks Spicy                   0.000000             0.107623
# Voodoo Fries - Large                  0.000854             0.045405
# Voodoo Fries - Regular                0.001444             0.083987
# Wings Lunch Combo                     0.000000             0.002251
#
# item_name                  10 pc Grilled Wings Combo  10 pc Mixed Wings  \
# ...

# %%
def get_personalized_recommendations(cart_items, similarity_df):
    """Generates personalized recommendations using an item similarity matrix."""
    
    similar_scores = pd.Series(dtype=float)

    # For each item in the cart, get its similarity scores with all other items
    for item in cart_items:
        if item in similarity_df.columns:
            # Use concat to append the series of scores for the current item
            similar_scores = pd.concat([similar_scores, similarity_df[item]])
    
    # If no items in the cart are in our model, we can't recommend anything
    if similar_scores.empty:
        return ["N/A", "N/A", "N/A"]

    # Group by item name and take the mean similarity score
    grouped_scores = similar_scores.groupby(similar_scores.index).mean()

    # Sort the items by their average similarity score in descending order
    sorted_scores = grouped_scores.sort_values(ascending=False)

    # Filter out any items that are already in the cart
    recommendations = [item for item in sorted_scores.index if item not in cart_items]
    
    # Pad with placeholders if we have fewer than 3 recommendations
    while len(recommendations) < 3:
        recommendations.append("N/A")
        
    return recommendations[:3]

# %%
# Example cart for a loyal customer
example_cart = {'6pc Boneless Mild', 'Large Cheese Fries', '20 Oz Soda'}

# Call the personalized recommendation function
personalized_recs = get_personalized_recommendations(example_cart, item_similarity_df_loyal)

print(f"For the cart: {example_cart}")
print(f"Personalized recommendations are: {personalized_recs}")
# Out:
# For the cart: {'20 Oz Soda', 'Large Cheese Fries', '6pc Boneless Mild'}
# Personalized recommendations are: ['20pc Spicy Feast Deal', 'Ranch Dip - Regular', '32 Oz Soda']

# %% [markdown]
# ### Exporting Registered and Loyal customers data

# %%
df1.to_csv('loyal_customer_data.csv', index=False)

# %% [markdown]
# # 2. Guest

# %%
df2 = df_edible_cust3[df_edible_cust3['CUSTOMER_TYPE'] == 'Guest']
df2
# Out:
#            ORDER_ID  CUSTOMER_ID  STORE_NUMBER ORDER_CREATED_DATE  \
# 8        7575285208    585330633          2249         2025-02-15
# 18       7150407872    434985772          1754         2024-04-08
# 19       7150407872    434985772          1754         2024-04-08
# 26       1655782790    426992703          2156         2025-02-15
# 28       1655782790    426992703          2156         2025-02-15
# ...             ...          ...           ...                ...
# 5657278  9371418183    125634365          1419         2025-01-22
# 5657281  8082200700    125634365          4595         2025-02-13
# 5657283  8865782702    125634365          1419         2024-11-30
# 5657284  8030111101    125634365          4595         2024-12-16
# 5657285  8030111101    125634365          4595         2024-12-16
#
#         ORDER_CHANNEL_NAME ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME  \
# 8                  Digital                   WWT                ToGo
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules

# Create transactions from the guest dataframe
transactions_guest = df2.groupby('ORDER_ID')['item_name'].apply(list).tolist()

# One-hot encode the guest transactions
te_guest = TransactionEncoder()
te_ary_guest = te_guest.fit(transactions_guest).transform(transactions_guest)
market_basket_guest = pd.DataFrame(te_ary_guest, columns=te_guest.columns_)

market_basket_guest
# Out:
#         $19.99 Crispy Feast  10 pc Grilled Wings  10 pc Grilled Wings Combo  \
# 0                     False                False                      False
# 1                     False                False                      False
# 2                     False                False                      False
# 3                     False                False                      False
# 4                     False                False                      False
# ...                     ...                  ...                        ...
# 271540                False                 True                      False
# 271541                False                False                      False
# 271542                False                False                      False
# 271543                False                False                      False
# 271544                False                False                      False
#
# ...

# %%
# Find frequent itemsets for guests
frequent_itemsets_guest = fpgrowth(market_basket_guest, min_support=0.001, use_colnames=True)

# Generate the final association rules for guests
rules_guest = association_rules(frequent_itemsets_guest, metric="lift", min_threshold=1)

print("✅ FP-Growth model for Guest customers is trained.")

rules_guest
# Out:
# ✅ FP-Growth model for Guest customers is trained.
#                                            antecedents  \
# 0                         (24 pc Family Grilled Wings)
# 1                                (Large Buffalo Fries)
# 2                           (8 pc Grilled Wings Combo)
# 3                                (Ranch Dip - Regular)
# 4    (10 pc Grilled Wings Combo, 8 pc Grilled Wings...
# ..                                                 ...
# 739                              (Ranch Dip - Regular)
# 740                                   (3 Strips Lunch)
# 741                              (Ranch Dip - Regular)
# 742                                (15 pc Mixed Wings)
# 743                              (Ranch Dip - Regular)
#
#                       consequents  antecedent support  consequent support  \
# 0           (Large Buffalo Fries)            0.023576            0.040421
# 1    (24 pc Family Grilled Wings)            0.040421            0.023576
# ...

# %%
def get_guest_recommendations(cart_items, rules_df):
    """Generates non-personalized recommendations using association rules."""
    
    # Find rules where the 'antecedents' are a subset of the items in the cart
    matching_rules = rules_df[rules_df['antecedents'].apply(lambda x: x.issubset(cart_items))]

    if matching_rules.empty:
        return ["N/A", "N/A", "N/A"]

    # Sort the matching rules by 'lift' to prioritize the strongest associations
    sorted_rules = matching_rules.sort_values(by='lift', ascending=False)
    
    # Extract the recommended items (consequents)
    recommendations = sorted_rules['consequents'].explode().unique()
    
    # Filter out items that are already in the cart
    final_recs = [rec for rec in recommendations if rec not in cart_items]
    
    # Pad with placeholders if we have fewer than 3 recommendations
    while len(final_recs) < 3:
        final_recs.append("N/A")

    return final_recs[:3]

# %%
# Example cart for a guest customer
example_guest_cart = {'6pc Boneless Mild', 'Large Cheese Fries', '20 Oz Soda'}

# Call the guest recommendation function with the guest rules
guest_recs = get_guest_recommendations(example_guest_cart, rules_guest)

print(f"For the guest cart: {example_guest_cart}")
print(f"Guest recommendations are: {guest_recs}")
# Out:
# For the guest cart: {'20 Oz Soda', 'Large Cheese Fries', '6pc Boneless Mild'}
# Guest recommendations are: ['10 pc Spicy Wings', 'Regular Buffalo Fries', '20pc Spicy Feast Deal']

# %% [markdown]
# ### Exporting Guest customers data

# %%
df2.to_csv('guest_customer_data.csv', index=False)

# %% [markdown]
# # Dumping the ML models

# %%
import joblib

# --- Save the trained FP-Growth model ---
# The model is the 'rules_guest' DataFrame
joblib.dump(rules_guest, 'guest_fp_growth_model.joblib')

# --- Save the trained Collaborative Filtering model ---
# The model is the 'item_similarity_df_loyal' DataFrame
joblib.dump(item_similarity_df_loyal, 'loyal_collab_filtering_model.joblib')

print("✅ Both models have been trained and saved successfully as joblib files.")
# Out:
# ✅ Both models have been trained and saved successfully as joblib files.

# %% [markdown]
# # Manager Recommendation Function

# %%
def get_final_recommendations(cart_items, customer_type, rules_guest, item_similarity_df_loyal):
    """
    This function acts as a manager, choosing the correct model based on customer type.
    """
    
    # If the customer is a Guest, use the FP-Growth model
    if customer_type == 'Guest':
        return get_guest_recommendations(cart_items, rules_guest)
        
    # If the customer is Registered or eClub, use the personalized Collaborative Filtering model
    else: # This covers 'Registered' and 'eClub'
        return get_personalized_recommendations(cart_items, item_similarity_df_loyal)

# %% [markdown]
# # Applying Manager Recommendation Function in our Test data

# %%
test_data
# Out:
#      CUSTOMER_ID  STORE_NUMBER    ORDER_ID ORDER_CHANNEL_NAME  \
# 0      997177535          4915  9351345556            Digital
# 1      345593831           949  3595377080            Digital
# 2      160955031          2249  4071757785            Digital
# 3      890671991          4154  3931766769            Digital
# 4       73989021          4094  3739700809            Digital
# ..           ...           ...         ...                ...
# 995    199551661          4915  5790578362            Digital
# 996    324907688          1161   371107248            Digital
# 997    688871063           949  7519184133            Digital
# 998    529892223          4750  8800902863            Digital
# 999    986902731          1731  2611475190            Digital
#
#     ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME CUSTOMER_TYPE  \
# 0                     WWT                ToGo         Guest
# 1                     WWT                ToGo    Registered
# ...

# %%
test_data['item4'] = 'Missing'
test_data
# Out:
#      CUSTOMER_ID  STORE_NUMBER    ORDER_ID ORDER_CHANNEL_NAME  \
# 0      997177535          4915  9351345556            Digital
# 1      345593831           949  3595377080            Digital
# 2      160955031          2249  4071757785            Digital
# 3      890671991          4154  3931766769            Digital
# 4       73989021          4094  3739700809            Digital
# ..           ...           ...         ...                ...
# 995    199551661          4915  5790578362            Digital
# 996    324907688          1161   371107248            Digital
# 997    688871063           949  7519184133            Digital
# 998    529892223          4750  8800902863            Digital
# 999    986902731          1731  2611475190            Digital
#
#     ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME CUSTOMER_TYPE  \
# 0                     WWT                ToGo         Guest
# 1                     WWT                ToGo    Registered
# ...

# %%
# A list to store the final recommendations for each order
recommendations_list = []

# Loop through each row of the test_data
for index, row in test_data.iterrows():
    # Create the cart from the item columns
    cart = {row['item1'], row['item2'], row['item3']}
    
    # Get the customer type for this order
    cust_type = row['CUSTOMER_TYPE']
    
    # Call the single manager function with all the necessary info
    recommendations = get_final_recommendations(
        cart, 
        cust_type, 
        rules_guest,                 # Pass in the trained guest model
        item_similarity_df_loyal     # Pass in the trained loyal customer model
    )
    
    recommendations_list.append(recommendations)

# --- Create the final submission DataFrame ---
# Convert the list of recommendations into a DataFrame
recommendations_df = pd.DataFrame(recommendations_list, columns=['RECOMMENDATION 1', 'RECOMMENDATION 2', 'RECOMMENDATION 3'])

# Assign the new columns to your original test_data
test_data[['RECOMMENDATION 1', 'RECOMMENDATION 2', 'RECOMMENDATION 3']] = recommendations_df

print("✅ Recommendations have been successfully added to the test data.")
test_data
# Out:
# ✅ Recommendations have been successfully added to the test data.
#      CUSTOMER_ID  STORE_NUMBER    ORDER_ID ORDER_CHANNEL_NAME  \
# 0      997177535          4915  9351345556            Digital
# 1      345593831           949  3595377080            Digital
# 2      160955031          2249  4071757785            Digital
# 3      890671991          4154  3931766769            Digital
# 4       73989021          4094  3739700809            Digital
# ..           ...           ...         ...                ...
# 995    199551661          4915  5790578362            Digital
# 996    324907688          1161   371107248            Digital
# 997    688871063           949  7519184133            Digital
# 998    529892223          4750  8800902863            Digital
# 999    986902731          1731  2611475190            Digital
#
#     ORDER_SUBCHANNEL_NAME ORDER_OCCASION_NAME CUSTOMER_TYPE  \
# 0                     WWT                ToGo         Guest
# ...

# %%
test_data.isna().sum()
# Out:
# CUSTOMER_ID              0
# STORE_NUMBER             0
# ORDER_ID                 0
# ORDER_CHANNEL_NAME       0
# ORDER_SUBCHANNEL_NAME    0
# ORDER_OCCASION_NAME      0
# CUSTOMER_TYPE            0
# item1                    0
# item2                    0
# item3                    0
# item4                    0
# RECOMMENDATION 1         0
# RECOMMENDATION 2         0
# RECOMMENDATION 3         0
# dtype: int64

# %%
test_data.duplicated().sum()
# Out:
# 0

# %%
test_data.to_csv('submission.csv', index=False)
